# %%
from plotly_calplot import calplot
import pandas as pd
import nbformat

df = pd.read_csv("df.csv")
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#           date  value
# 0   2024-10-01      1
# 1   2024-10-02      2
# 2   2024-10-03      3
# 3   2024-10-04      4
# 4   2024-10-05      5
# ..         ...    ...
# 360 2025-09-26    361
# 361 2025-09-27    362
# 362 2025-09-28    363
# 363 2025-09-29    364
# 364 2025-09-30    365
#
# [365 rows x 2 columns]

# %%
fig = calplot(df, x="date", y="value")
fig.show()

# %%
fig.write_html("calplot.html")
